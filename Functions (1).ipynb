# %% [markdown]
# # Functions

# %% [markdown]
# 1. what is diffrence between functions and a methord in python?
#    - hi this khan your personal coach for your goal and training. be focused on your goal. i will absorb you and guide you where you can improve your game.
# 2. tell me about your self?
#    - this is deepak. your coach.

# %%
# questions
'''
1. what is diffrence between functions and a methord in python?
2. tell me about your self?
'''
